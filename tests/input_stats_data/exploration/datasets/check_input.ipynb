# %%
import argparse
import json
from collections import Counter, namedtuple
import itertools
import sys
import os

import pandas as pd


# rep_1000000s_sim_500000t_abcde__100_100.s
class Input(namedtuple('fn', 'st sl tt tl alp rep_mut sim_mut rep_block'.split())):
    @classmethod
    def from_fn(cls, fname, cfg_path='input_spec.json'):
        with open(cfg_path) as fd:
            rep_block = json.load(fd)['rep_block']

        a, b = fname.split('__')
        st, sl, tt, tl, alp = a.split('_')
        rep_mut, sim_mut = b[:-2].split("_")
        return cls(st, int(sl[:-1]), tt, int(tl[:-1]), alp, int(rep_mut), int(sim_mut), rep_block)

    @property
    def num_blocks(self):
        return self.rep_block
    @property
    def block_len(self):
        return self.sl / self.num_blocks

    def path(self, which):
        return "{st}_{sl}s_{tt}_{tl}t_{alp}__{rep_mut}_{sim_mut}.{w}".format(w=which, **self._asdict())

    def _split_in_blocks(self):
        from operator import  itemgetter

        with open('data_dir/' + self.path('s')) as fd:
            s = fd.read().strip()

        res = []
        for k, giter in itertools.groupby(enumerate(s), key=lambda (i, c): i / self.block_len):
            res.append("".join(map(itemgetter(1), giter)))
        return res
            
    def s_mutations(self):
        blocks = self._split_in_blocks()
        m = []
        for i in range(1, len(blocks)):
            m.append(sum(c1 != c2 for c1, c2 in zip(blocks[0], blocks[i])))
        l = map(lambda b: len(b) == self.block_len, blocks)
        assert all(l)
        assert len(l) == len(m) + 1
        return pd.Series(m)

    def t_mutations(self):
        with open('data_dir/' + self.path('s')) as fd:
            s = fd.read().strip()
        with open('data_dir/' + self.path('t')) as fd:
            t = fd.read().strip()
        return sum(c1 != c2 for c1, c2 in zip(s, t))

    def report(self):
        smut = self.s_mutations()
        print smut.describe()        
        tmut = self.t_mutations()
        print tmut

with open('input_spec.json') as fd:
    cfg = json.load(fd)

res = []
for rm, sm, alp in itertools.product(cfg['rep_mut'], cfg['sim_mut'], cfg['alp']):
    i = Input.from_fn('rep_100000s_sim_80000t_{alp}__{rm}_{sm}.s'.format(rm=rm, sm=sm, alp=alp))
    s_mut = i.s_mutations()
    res.append([i.path('s'), i.rep_mut, s_mut.mean(), s_mut.std(), i.sim_mut, i.t_mutations()])
    print i

pd.DataFrame(data=res, columns=['path', 's_exp', 's_found_avg', 's_found_std', 't_exp', 't_found'])
# Out:
# fn(st='rep', sl=100000, tt='sim', tl=80000, alp='abcde', rep_mut=1, sim_mut=1, rep_block=1000)
# fn(st='rep', sl=100000, tt='sim', tl=80000, alp='abcdefghijklmnopqrst', rep_mut=1, sim_mut=1, rep_block=1000)
# fn(st='rep', sl=100000, tt='sim', tl=80000, alp='abcde', rep_mut=1, sim_mut=10, rep_block=1000)
# fn(st='rep', sl=100000, tt='sim', tl=80000, alp='abcdefghijklmnopqrst', rep_mut=1, sim_mut=10, rep_block=1000)
# fn(st='rep', sl=100000, tt='sim', tl=80000, alp='abcde', rep_mut=1, sim_mut=100, rep_block=1000)
# fn(st='rep', sl=100000, tt='sim', tl=80000, alp='abcdefghijklmnopqrst', rep_mut=1, sim_mut=100, rep_block=1000)
# fn(st='rep', sl=100000, tt='sim', tl=80000, alp='abcde', rep_mut=10, sim_mut=1, rep_block=1000)
# fn(st='rep', sl=100000, tt='sim', tl=80000, alp='abcdefghijklmnopqrst', rep_mut=10, sim_mut=1, rep_block=1000)
# fn(st='rep', sl=100000, tt='sim', tl=80000, alp='abcde', rep_mut=10, sim_mut=10, rep_block=1000)
# fn(st='rep', sl=100000, tt='sim', tl=80000, alp='abcdefghijklmnopqrst', rep_mut=10, sim_mut=10, rep_block=1000)
# fn(st='rep', sl=100000, tt='sim', tl=80000, alp='abcde', rep_mut=10, sim_mut=100, rep_block=1000)
# fn(st='rep', sl=100000, tt='sim', tl=80000, alp='abcdefghijklmnopqrst', rep_mut=10, sim_mut=100, rep_block=1000)
# fn(st='rep', sl=100000, tt='sim', tl=80000, alp='abcde', rep_mut=100, sim_mut=1, rep_block=1000)
# fn(st='rep', sl=100000, tt='sim', tl=80000, alp='abcdefghijklmnopqrst', rep_mut=100, sim_mut=1, rep_block=1000)
# fn(st='rep', sl=100000, tt='sim', tl=80000, alp='abcde', rep_mut=100, sim_mut=10, rep_block=1000)
# fn(st='rep', sl=100000, tt='sim', tl=80000, alp='abcdefghijklmnopqrst', rep_mut=100, sim_mut=10, rep_block=1000)
# fn(st='rep', sl=100000, tt='sim', tl=80000, alp='abcde', rep_mut=100, sim_mut=100, rep_block=1000)
# fn(st='rep', sl=100000, tt='sim', tl=80000, alp='abcdefghijklmnopqrst', rep_mut=100, sim_mut=100, rep_block=1000)
#                                                  path  s_exp  s_found_avg  \
# 0                 rep_100000s_sim_80000t_abcde__1_1.s      1          1.0
# 1   rep_100000s_sim_80000t_abcdefghijklmnopqrst__1...      1          1.0
# 2                rep_100000s_sim_80000t_abcde__1_10.s      1          1.0
# 3   rep_100000s_sim_80000t_abcdefghijklmnopqrst__1...      1          1.0
# 4               rep_100000s_sim_80000t_abcde__1_100.s      1          1.0
# 5   rep_100000s_sim_80000t_abcdefghijklmnopqrst__1...      1          1.0
# 6                rep_100000s_sim_80000t_abcde__10_1.s     10         10.0
# 7   rep_100000s_sim_80000t_abcdefghijklmnopqrst__1...     10         10.0
# 8               rep_100000s_sim_80000t_abcde__10_10.s     10         10.0
# 9   rep_100000s_sim_80000t_abcdefghijklmnopqrst__1...     10         10.0
# 10             rep_100000s_sim_80000t_abcde__10_100.s     10         10.0
# 11  rep_100000s_sim_80000t_abcdefghijklmnopqrst__1...     10         10.0
# 12              rep_100000s_sim_80000t_abcde__100_1.s    100        100.0
# 13  rep_100000s_sim_80000t_abcdefghijklmnopqrst__1...    100        100.0
# 14             rep_100000s_sim_80000t_abcde__100_10.s    100        100.0
# 15  rep_100000s_sim_80000t_abcdefghijklmnopqrst__1...    100        100.0
# 16            rep_100000s_sim_80000t_abcde__100_100.s    100        100.0
# 17  rep_100000s_sim_80000t_abcdefghijklmnopqrst__1...    100        100.0
#
#     s_found_std  t_exp  t_found
# 0           0.0      1        1
# 1           0.0      1        1
# 2           0.0     10       10
# 3           0.0     10       10
# 4           0.0    100      100
# 5           0.0    100      100
# 6           0.0      1        1
# 7           0.0      1        1
# 8           0.0     10       10
# 9           0.0     10       10
# 10          0.0    100      100
# 11          0.0    100      100
# 12          0.0      1        1
# 13          0.0      1        1
# 14          0.0     10       10
# 15          0.0     10       10
# 16          0.0    100      100
# 17          0.0    100      100

# %%
i.num_blocks
# Out:
# 1000

# %%
s = open('data_dir/' + i.path('s')).read()
t = open('data_dir/' + i.path('t')).read()

len(s), len(t)
# Out:
# (10000, 500)
