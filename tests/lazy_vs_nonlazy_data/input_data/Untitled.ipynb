# %%
with open('mut_100Ms_5Mt_10.s') as fd:
    s = fd.read(1000)
with open('mut_100Ms_5Mt_10.t') as fd:
    t = fd.read(1000)

list(enumerate(map(lambda aa: aa + (aa[0] == aa[1],),  zip(s, t))))
# Out:
# [(0, ('i', 'h', False)),
#  (1, ('j', 'j', True)),
#  (2, ('r', 'r', True)),
#  (3, ('r', 'r', True)),
#  (4, ('d', 'd', True)),
#  (5, ('p', 'p', True)),
#  (6, ('m', 'm', True)),
#  (7, ('a', 'a', True)),
#  (8, ('f', 'f', True)),
#  (9, ('l', 'l', True)),
#  (10, ('o', 'd', False)),
#  (11, ('c', 'c', True)),
#  (12, ('h', 'h', True)),
#  (13, ('l', 'l', True)),
#  (14, ('t', 't', True)),
#  (15, ('e', 'e', True)),
#  (16, ('g', 'g', True)),
#  (17, ('l', 'l', True)),
#  (18, ('a', 'a', True)),
#  (19, ('a', 'a', True)),
#  (20, ('h', 'p', False)),
#  (21, ('c', 'c', True)),
#  (22, ('h', 'h', True)),
#  (23, ('l', 'l', True)),
#  (24, ('c', 'c', True)),
#  (25, ('e', 'e', True)),
#  (26, ('f', 'f', True)),
#  (27, ('h', 'h', True)),
#  (28, ('o', 'o', True)),
#  (29, ('p', 'p', True)),
#  (30, ('p', 'e', False)),
#  (31, ('c', 'c', True)),
#  (32, ('j', 'j', True)),
#  (33, ('g', 'g', True)),
#  (34, ('k', 'k', True)),
#  (35, ('b', 'b', True)),
#  (36, ('d', 'd', True)),
# ...
