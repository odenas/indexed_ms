# %%
# %matplotlib inline 
# %load_ext autoreload
# %autoreload 2
import sys
from collections import OrderedDict
import numpy as np
import pandas as pd

sys.path.append("../")
from utils import FullIndex, ms_table

#s = 'bcdbaecdcd'
s = open('testing/rnd_200_64.s').read().strip()[::-1]
t = 'dcdceabdcbdcdceabdcb'

s_index = FullIndex(s)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
a, b = s_index.sa_interval('', FullIndex.FWD)
print "(0, 0) %s [%d, %d] --> %s" % ('', a, b, s_index.is_maximal_s(''))

for i in range(len(s)):
    for j in range(i + 1, len(s)):
        substr = s[i:j]
        if not s_index.is_node(substr):
            continue
        a, b = s_index.sa_interval(substr, FullIndex.FWD)
        print "(%d, %d) %s [%d, %d] --> %s" % (i, j, substr, a, b, s_index.is_maximal_s(substr))
    if i > 15:
        break
# Out:
# (0, 0)  [0, 65] --> True
# (0, 1) e [59, 65] --> True
# (0, 2) ed [62, 65] --> True
# (0, 3) edd [63, 65] --> True
# (1, 2) d [44, 59] --> True
# (1, 3) dd [52, 55] --> True
# (2, 3) d [44, 59] --> True
# (2, 4) da [44, 47] --> True
# (3, 4) a [1, 16] --> True
# (3, 5) ad [11, 15] --> True
# (3, 6) adc [12, 14] --> True
# (4, 5) d [44, 59] --> True
# (4, 6) dc [49, 52] --> True
# (5, 6) c [27, 44] --> True
# (5, 7) ca [27, 30] --> True
# (5, 8) caa [27, 29] --> True
# (6, 7) a [1, 16] --> True
# (6, 8) aa [2, 7] --> True
# (7, 8) a [1, 16] --> True
# (7, 9) ac [8, 11] --> True
# (7, 10) acb [8, 10] --> True
# (8, 9) c [27, 44] --> True
# (8, 10) cb [30, 35] --> True
# (9, 10) b [16, 27] --> True
# (9, 11) ba [16, 20] --> True
# (10, 11) a [1, 16] --> True
# (11, 12) b [16, 27] --> True
# (11, 13) ba [16, 20] --> True
# (12, 13) a [1, 16] --> True
# (12, 14) ac [8, 11] --> True
# (12, 15) acb [8, 10] --> True
# (13, 14) c [27, 44] --> True
# (13, 15) cb [30, 35] --> True
# (14, 15) b [16, 27] --> True
# (15, 16) d [44, 59] --> True
# (15, 17) de [55, 59] --> True
# (15, 18) ded [57, 59] --> True
# (16, 17) e [59, 65] --> True
# (16, 18) ed [62, 65] --> True
# (16, 19) edd [63, 65] --> True

# %%
#table2(s)#[50:80]
#index_table(s)
s_index.tabs[FullIndex.FWD]
# Out:
#    s_i BWT  SA                                            suff_SA
# i
# 0    e   a  64                                                  #
# 1    d   a  63                                                 a#
# 2    d   a  62                                                aa#
# 3    a   b  61                                               aaa#
# 4    d   c   6  aacbabacbdedddbbcbccaadcccdebcadaaecccdacdecbc...
# 5    c   c  26            aadcccdebcadaaecccdacdecbcdbadedcbbaaa#
# 6    a   d  38                        aaecccdacdecbcdbadedcbbaaa#
# 7    a   b  10  abacbdedddbbcbccaadcccdebcadaaecccdacdecbcdbad...
# 8    c   a   7  acbabacbdedddbbcbccaadcccdebcadaaecccdacdecbcd...
# 9    b   b  12  acbdedddbbcbccaadcccdebcadaaecccdacdecbcdbaded...
# 10   a   d  45                               acdecbcdbadedcbbaaa#
# 11   b   c  36                      adaaecccdacdecbcdbadedcbbaaa#
# 12   a   d   3  adcaacbabacbdedddbbcbccaadcccdebcadaaecccdacde...
# 13   c   a  27             adcccdebcadaaecccdacdecbcdbadedcbbaaa#
# 14   b   b  54                                        adedcbbaaa#
# 15   d   a  39                         aecccdacdecbcdbadedcbbaaa#
# 16   e   b  60                                              baaa#
# 17   d   c   9  babacbdedddbbcbccaadcccdebcadaaecccdacdecbcdba...
# 18   d   a  11  bacbdedddbbcbccaadcccdebcadaaecccdacdecbcdbade...
# 19   d   d  53                                       badedcbbaaa#
# 20   b   c  59                                             bbaaa#
# 21   b   d  20      bbcbccaadcccdebcadaaecccdacdecbcdbadedcbbaaa#
# 22   c   e  34                    bcadaaecccdacdecbcdbadedcbbaaa#
# 23   b   b  21       bcbccaadcccdebcadaaecccdacdecbcdbadedcbbaaa#
# 24   c   c  23         bccaadcccdebcadaaecccdacdecbcdbadedcbbaaa#
# 25   c   c  50                                    bcdbadedcbbaaa#
# 26   a   c  14  bdedddbbcbccaadcccdebcadaaecccdacdecbcdbadedcb...
# 27   a   d   5  caacbabacbdedddbbcbccaadcccdebcadaaecccdacdecb...
# 28   d   c  25           caadcccdebcadaaecccdacdecbcdbadedcbbaaa#
# 29   c   b  35                     cadaaecccdacdecbcdbadedcbbaaa#
# ..  ..  ..  ..                                                ...
# 35   c   b  24          ccaadcccdebcadaaecccdacdecbcdbadedcbbaaa#
# 36   a   e  41                           cccdacdecbcdbadedcbbaaa#
# 37   d   d  29               cccdebcadaaecccdacdecbcdbadedcbbaaa#
# 38   a   c  42                            ccdacdecbcdbadedcbbaaa#
# 39   a   c  30                ccdebcadaaecccdacdecbcdbadedcbbaaa#
# 40   e   c  43                             cdacdecbcdbadedcbbaaa#
# 41   c   b  51                                     cdbadedcbbaaa#
# 42   c   c  31                 cdebcadaaecccdacdecbcdbadedcbbaaa#
# 43   c   a  46                                cdecbcdbadedcbbaaa#
# 44   d   a  37                       daaecccdacdecbcdbadedcbbaaa#
# 45   a   c  44                              dacdecbcdbadedcbbaaa#
# 46   c   d   2  dadcaacbabacbdedddbbcbccaadcccdebcadaaecccdacd...
# 47   d   c  52                                      dbadedcbbaaa#
# 48   e   d  19     dbbcbccaadcccdebcadaaecccdacdecbcdbadedcbbaaa#
# 49   c   a   4  dcaacbabacbdedddbbcbccaadcccdebcadaaecccdacdec...
# 50   b   e  57                                           dcbbaaa#
# 51   c   a  28              dcccdebcadaaecccdacdecbcdbadedcbbaaa#
# 52   d   e   1  ddadcaacbabacbdedddbbcbccaadcccdebcadaaecccdac...
# 53   b   d  18    ddbbcbccaadcccdebcadaaecccdacdecbcdbadedcbbaaa#
# 54   a   e  17   dddbbcbccaadcccdebcadaaecccdacdecbcdbadedcbbaaa#
# 55   d   c  32                  debcadaaecccdacdecbcdbadedcbbaaa#
# 56   e   c  47                                 decbcdbadedcbbaaa#
# 57   d   a  55                                         dedcbbaaa#
# 58   c   b  15  dedddbbcbccaadcccdebcadaaecccdacdecbcdbadedcbb...
# 59   b   d  33                   ebcadaaecccdacdecbcdbadedcbbaaa#
# 60   b   d  48                                  ecbcdbadedcbbaaa#
# 61   a   a  40                          ecccdacdecbcdbadedcbbaaa#
# 62   a   d  56                                          edcbbaaa#
# 63   a   #   0  eddadcaacbabacbdedddbbcbccaadcccdebcadaaecccda...
# 64   #   d  16  edddbbcbccaadcccdebcadaaecccdacdecbcdbadedcbbaaa#
#
# [65 rows x 4 columns]

# %%
s_index.tabs[FullIndex.REV]
# Out:
#    s_i BWT  SA                                            suff_SA
# i
# 0    a   e  64                                                  #
# 1    a   #   0  aaabbcdedabdcbcedcadccceaadacbedcccdaaccbcbbdd...
# 2    a   a   1  aabbcdedabdcbcedcadccceaadacbedcccdaaccbcbbddd...
# 3    b   d  36                      aaccbcbbdddedbcababcaacdadde#
# 4    b   c  56                                          aacdadde#
# 5    c   e  24          aadacbedcccdaaccbcbbdddedbcababcaacdadde#
# 6    d   c  51                                     ababcaacdadde#
# 7    e   a   2  abbcdedabdcbcedcadccceaadacbedcccdaaccbcbbddde...
# 8    d   b  53                                       abcaacdadde#
# 9    a   d   9  abdcbcedcadccceaadacbedcccdaaccbcbbdddedbcabab...
# 10   b   d  27             acbedcccdaaccbcbbdddedbcababcaacdadde#
# 11   d   a  37                       accbcbbdddedbcababcaacdadde#
# 12   c   a  57                                           acdadde#
# 13   b   a  25           adacbedcccdaaccbcbbdddedbcababcaacdadde#
# 14   c   c  18    adccceaadacbedcccdaaccbcbbdddedbcababcaacdadde#
# 15   e   d  60                                              adde#
# 16   d   a  52                                      babcaacdadde#
# 17   c   a   3  bbcdedabdcbcedcadccceaadacbedcccdaaccbcbbddded...
# 18   a   c  42                            bbdddedbcababcaacdadde#
# 19   d   a  54                                        bcaacdadde#
# 20   c   d  49                                   bcababcaacdadde#
# 21   c   c  40                          bcbbdddedbcababcaacdadde#
# 22   c   b   4  bcdedabdcbcedcadccceaadacbedcccdaaccbcbbdddedb...
# 23   e   c  13  bcedcadccceaadacbedcccdaaccbcbbdddedbcababcaac...
# 24   a   a  10  bdcbcedcadccceaadacbedcccdaaccbcbbdddedbcababc...
# 25   a   b  43                             bdddedbcababcaacdadde#
# 26   d   c  29               bedcccdaaccbcbbdddedbcababcaacdadde#
# 27   a   b  55                                         caacdadde#
# 28   c   b  50                                    cababcaacdadde#
# 29   b   d  17   cadccceaadacbedcccdaaccbcbbdddedbcababcaacdadde#
# ..  ..  ..  ..                                                ...
# 35   d   d  32                  cccdaaccbcbbdddedbcababcaacdadde#
# 36   a   d  20      ccceaadacbedcccdaaccbcbbdddedbcababcaacdadde#
# 37   a   c  33                   ccdaaccbcbbdddedbcababcaacdadde#
# 38   c   c  21       cceaadacbedcccdaaccbcbbdddedbcababcaacdadde#
# 39   c   c  34                    cdaaccbcbbdddedbcababcaacdadde#
# 40   b   a  58                                            cdadde#
# 41   c   b   5  cdedabdcbcedcadccceaadacbedcccdaaccbcbbdddedbc...
# 42   b   c  22        ceaadacbedcccdaaccbcbbdddedbcababcaacdadde#
# 43   b   b  14  cedcadccceaadacbedcccdaaccbcbbdddedbcababcaacd...
# 44   d   c  35                     daaccbcbbdddedbcababcaacdadde#
# 45   d   e   8  dabdcbcedcadccceaadacbedcccdaaccbcbbdddedbcaba...
# 46   d   a  26            dacbedcccdaaccbcbbdddedbcababcaacdadde#
# 47   e   c  59                                             dadde#
# 48   d   e  48                                  dbcababcaacdadde#
# 49   b   e  16  dcadccceaadacbedcccdaaccbcbbdddedbcababcaacdadde#
# 50   c   b  11  dcbcedcadccceaadacbedcccdaaccbcbbdddedbcababca...
# 51   a   e  31                 dcccdaaccbcbbdddedbcababcaacdadde#
# 52   b   a  19     dccceaadacbedcccdaaccbcbbdddedbcababcaacdadde#
# 53   a   b  44                              dddedbcababcaacdadde#
# 54   b   a  61                                               dde#
# 55   c   d  45                               ddedbcababcaacdadde#
# 56   a   d  62                                                de#
# 57   a   c   6  dedabdcbcedcadccceaadacbedcccdaaccbcbbdddedbca...
# 58   c   d  46                                dedbcababcaacdadde#
# 59   d   d  63                                                 e#
# 60   a   c  23         eaadacbedcccdaaccbcbbdddedbcababcaacdadde#
# 61   d   d   7  edabdcbcedcadccceaadacbedcccdaaccbcbbdddedbcab...
# 62   d   d  47                                 edbcababcaacdadde#
# 63   e   c  15  edcadccceaadacbedcccdaaccbcbbdddedbcababcaacda...
# 64   #   b  30                edcccdaaccbcbbdddedbcababcaacdadde#
#
# [65 rows x 4 columns]
