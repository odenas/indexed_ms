# %%
from mstat import indexes

# %%
def get_s(fname):
    with open(fname) as fd:
        return fd.read().strip()

s = get_s('m.s')
t = get_s('m.t')
print(s)
print(t)
idx = (indexes.MatchingStatistics.ms_table(t, s).assign(psum = lambda x: x.MS.cumsum()))
idx
# Out:
# bebbeabcaecdbddddaccdeacdebeeeaedbebdacecbdceaebbbbabcbacebabecdcebbaabdddaebbedbaccbdbadcaccdcdbeadabcbebddcdacdbeedcabbdcacdae
# abbabaaabbaa
#     t_i  MS  nzeros    ms  runs  psum
# i
# -1        1       0          -1     1
#  0    a   3       3  0001     0     4
#  1    b   4       2   001     0     8
#  2    b   3       0     1     1    11
#  3    a   2       0     1     1    13
#  4    b   3       2   001     0    16
#  5    a   2       0     1     1    18
#  6    a   3       2   001     0    21
#  7    a   3       1    01     0    24
#  8    b   4       2   001     0    28
#  9    b   3       0     1     1    31
#  10   a   2       0     1     1    33
#  11   a   1       0     1     1    34

# %%
idx.psum.iloc[0]
# Out:
# 1
